# %% [markdown]
# # Practice

# %%
def a_star (start_node, stop_node):
    open_set = set (start_node)
    closed_set = set ()
    
    g = {}
    
    g[start_node] = 0
    
    parents = {}
    
    parents [start_node] = start_node
    
    
    
    while (len (open_set) > 0):
        n = None
        
        for v in open_set:
            if n == None or g[v] + heuristic(v) < g[n] + heuristic(n):
                n = v
        if n == stop_node or graph_nodes [n] == None:
            pass
        else:
            for (m, weight) in get_neigbhour (n):
                if m not in open_set or m not in closed_set:
                    open_set.add (m)
                    parents [m] = n
                    g[m] = g[n] + weight
                else:
                    if g[m] > g[n] + weight:
                        g[m] = g[n] + weight
                        parents [m] = n

                        if m in closed_set:
                            closed_set.remove (m)
                            open_set.add (m)
        
        if n == None:
            print ("path does not exist 1")
            return None

        if n == stop_node:
            path = []
            while (parents[n] != n):
                path.append (n)
                n = parents[n]
                
            path.append (start_node)
            
            path.reverse ()
            
            print ("path is : {}".format (path))
            return None
        open_set.remove (n)
        closed_set.add (n)
        print (n)
        print (open_set)
    print ("Path does not exist 2")
    return None

# %%
def heuristic (v):
    h = {
        'S':14,
        'B':12,
        'C':11,
        'D':6,
        'E':4,
        'F':11,
        'G':0
    }
    return h[v]

# %%
graph_nodes = {
    'S': [('B', 4), ('C', 3)],
    'B': [('F', 5)],
    'C': [('E', 10), ('D', 7)],
    'D': [('E', 2)],
    'E': [('G', 5)],
    'F':[('G', 16)],
    'G': [('G', 0)]
}

# %%
def get_neigbhour (n):
    if n in graph_nodes:
        return graph_nodes [n]
    else:
        return None

# %%
a_star ('S', 'G')
# Out:
# path is : ['S', 'C', 'D', 'E', 'G']

# %% [markdown]
# # Practice 2

# %%
def get_ne (v):
    if v in graph:
        return graph[v]
    else:
        return None

def heu (n):
    h = {
        'S':14,
        'B':12,
        'C':11,
        'D':6,
        'E':4,
        'F':11,
        'G':0
    }
    
    return h[n]
def a_star (start_node, stop_node):
    open_set  = set(start_node)
    closed_set = set()
    
    g = {}
    parents = {}
    
    g[start_node] = 0
    parents[start_node] = start_node
    
    while (len (open_set) > 0):
        
        n = None
        
        for v in open_set:
            if n == None or g[v] + heu(v) < g[n] + heu(n):
                n = v
        
        if n == stop_node or graph[n] == None:
            pass
        
        else:
            for (m, weight) in get_ne (n):
                
                if m not in closed_set or m not in open_set:
                    open_set.add (m)
                    g[m] = g[n] + weight
                    parents[m] = n
                
                else:
                    if g[m] > g[n] + weight:
                        g[m] = g[n] + weight
                        parents[m] = n
                        
                        if m in closed_set:
                            closed_set.remove (m)
                            open_set.add (m)
                            
            if n == None:
                print ("path does not exist")
                return None
            
        print (n)
        
        if n == stop_node:
            path = []

            while(parents[n] != n):
                path.append(n)
                n = parents[n]

            path.append (start_node)
            path.reverse ()

            print ("path is ", path)
            return None

        open_set.remove (n)
        closed_set.add (n)
    
    print ("path not found")
    return None



graph = {
    'S': [('B', 4), ('C', 3)],
    'B': [('F', 5)],
    'C': [('E', 10), ('D', 7)],
    'D': [('E', 2)],
    'E': [('G', 5)],
    'F':[('G', 16)],
    'G': [('G', 0)]
}

a_star ('S', 'G')
# Out:
# S
# C
# D
# E
# B
# G
# path is  ['S', 'C', 'D', 'E', 'G']
